# %%
import pandas 
import yfinance as web 
import plotly.graph_objects as go
import plotly.offline as plyo
import yfinance as api
import cufflinks as cf

# %%
sa = web.Ticker("bbas3.sa")

# %%
# sa.history(period="3mo").to_json()

df = sa.history( period= "3mo")
df = df.drop(df.tail(1).index)

# %%
fig = go.Figure(data=[go.Candlestick(x=df.index,
                       open=df['Open'], high=df['High'],
                       low=df['Low'], close=df['Close'] )], layout= go.Layout(paper_bgcolor="black"))

# %%
cf.set_config_file(theme='henanigans')
qf = cf.QuantFig(df=df)

# %%
# qf.add_bollinger_bands()

cf.getThemes()
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
qf = cf.QuantFig(df=df)

qf.add_volume()
qf.add_bollinger_bands()

fig = qf.figure()





fig
# Out:
# <div>                            <div id="d34821b3-94e0-4127-b34b-a341637fa71e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d34821b3-94e0-4127-b34b-a341637fa71e")) {                    Plotly.newPlot(                        "d34821b3-94e0-4127-b34b-a341637fa71e",                        [{"marker":{"color":["#808080","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF"],"line":{"color":["#808080","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF"],"width":1}},"name":"Volume","opacity":0.8,"orientation":"v","text":"","x":["2023-03-06 00:00:00-03:00","2023-03-07 00:00:00-03:00","2023-03-08 00: